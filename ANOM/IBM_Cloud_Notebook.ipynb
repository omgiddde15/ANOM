# %% [markdown]
# # ANOM AI - IBM SkillsBuild Project
#
# This notebook demonstrates the IBM SkillsBuild ANOM AI project.

# %%
print("ANOM AI - IBM SkillsBuild Project")

# %%
project = "ANOM AI"
service = "IBM watsonx.ai"
features = [
    "AI Personality Analysis",
    "Interest Matching",
    "Meeting Scheduler",
    "AI Conversation Starter"
]

print("Project:", project)
print("Service:", service)
print("Features:")
for f in features:
    print("-", f)
